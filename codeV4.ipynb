# %% [markdown]
# 无数据增强，但有图像缩小

# %%
import os
import numpy as np
import pandas as pd
import cv2
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import tensorflow as tf
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dropout

# %%
# 缩放标签坐标
def scale_labels(label_data, scale_percent):
    label_data[['LE_left', 'LE_top', 'LE_right', 'LE_bottom',
                'RE_left', 'RE_top', 'RE_right', 'RE_bottom',
                'lx', 'ly', 'rx', 'ry']] = label_data[['LE_left', 'LE_top', 'LE_right', 'LE_bottom',
                                                        'RE_left', 'RE_top', 'RE_right', 'RE_bottom',
                                                        'lx', 'ly', 'rx', 'ry']].astype(float)
    label_data[['LE_left', 'LE_top','LE_right', 'LE_bottom','RE_left', 'RE_top','RE_right','RE_bottom', 'lx', 'ly','rx','ry']] *= scale_percent
    return label_data

# 缩放和保存标签
def scale_and_save_labels(label_folder, output_label_folder, scale_percent):
    if not os.path.exists(output_label_folder):
        os.makedirs(output_label_folder)  #如果文件夹不存在，就创建该文件夹
    for label_file in os.listdir(label_folder):
        if label_file.endswith('.csv'):
            label_path = os.path.join(label_folder, label_file)
            output_label_path = os.path.join(output_label_folder, label_file)
            label_data = pd.read_csv(label_path)  #读取标签文件的数据
            scaled_label_data = scale_labels(label_data, scale_percent)  #将数据进行缩放
            scaled_label_data.to_csv(output_label_path, index=False)  #存储到csv文件里

# %%
# 加载图像和标签
def load_images_and_labels(image_folder, label_folder, target_size=(299, 299)):
    images = []
    labels = []
    #遍历标签文件
    for label_file in os.listdir(label_folder):
        if label_file.endswith('.csv'):
            participant_video = label_file[:-4]  ## 去除扩展名".csv"
            participant, video = participant_video.split('_')   ## 将csv的文件名如'001_0'划分为'001'和'0'

            # 构建图像文件夹路径
            image_folder_path = os.path.join(image_folder, participant, video)  ## 即获得'D:/Bristol/finalCoursework/dataset/ECL_Images_Test/001/0'

            if not os.path.isdir(image_folder_path):
                continue  #确保是有效目录
            label_path = os.path.join(label_folder, label_file) # 即'D:/Bristol/finalCoursework/dataset/ECL_Labels_Test/001_0.csv'
            label_data = pd.read_csv(label_path)
            for index, row in label_data.iterrows():
                image_name = row['filename']
                #image_folder_path = 'D:/Bristol/finalCoursework/dataset/ECL_Images_Test/'
                image_path = os.path.join(image_folder, image_name)
                print("文件path为：" + image_path)

                if not os.path.exists(image_path):
                    print(f"Image file does not exist: {image_path}")
                    continue
                
                image = cv2.imread(image_path)
                if image is None:
                    continue  #确保图像读取成功

                image = cv2.resize(image, target_size)

                #将处理后的图像存储到本地
                sanitized_image_name = image_name.replace(':', '_').replace(' ', '_') # 处理文件名中的非法字符
                output_image_path = os.path.join(output_image_folder, participant, video, sanitized_image_name)

                # 确保保存图像的目录存在
                os.makedirs(os.path.dirname(output_image_path), exist_ok=True)

                cv2.imwrite(output_image_path, image)
                if os.path.exists(output_image_path):
                    print(f"Saved processed image: {output_image_path}")
                else:
                    print(f"Failed to save processed image: {output_image_path}")

                label = row[['LE_left', 'LE_top', 'LE_right', 'LE_bottom',
                             'RE_left', 'RE_top', 'RE_right', 'RE_bottom',
                             'lx', 'ly', 'rx', 'ry']].values.astype('float32')  # 确保标签数据为 float32 类型
                images.append(image)
                labels.append(label)

                #归一化
                image = image.astype('float32')  # 转换图像数据类型为 float32
                image = preprocess_input(image)  # 使用预处理函数进行归一化

        print(f"Loaded {len(images)} images and {len(labels)} labels.")

    return np.array(images), np.array(labels)

#缩放标签并保存
label_folder = 'D:/Bristol/finalCoursework/dataset/ECL_Labels_Test'
output_label_folder = 'D:/Bristol/finalCoursework/dataset/ECL_Labels_Scaled'
scale_percent = 299/960  # 缩放比例为图片的缩放比例
scale_and_save_labels(label_folder, output_label_folder, scale_percent)

# 加载图像和标签
image_folder = 'D:/Bristol/finalCoursework/dataset/ECL_Images_Test'
output_image_folder = 'D:/Bristol/finalCoursework/dataset/Processed_Images'
#labels_folder = output_label_folder  # 使用缩放后的标签文件夹
label_folder = 'D:/Bristol/finalCoursework/dataset/ECL_Labels_Scaled'
#print("label_folder", label_folder)
#label_folder = 'D:/Bristol/finalCoursework/dataset/ECL_Labels_Scaled'
images, labels = load_images_and_labels(image_folder, label_folder, target_size=(299, 299))
print(f"Loaded {images.shape[0]} images with shape {images.shape[1:]} and {labels.shape[0]} labels.")
# Out:
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.792702-37704.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.792702-37704.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.101953-37752.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.101953-37752.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.818864-37708.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.818864-37708.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.225207-37772.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.225207-37772.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.126469-37756.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.126469-37756.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.609269-37676.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.609269-37676.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.491366-37816.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.491366-37816.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_18.217555-10736.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_18.217555-10736.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_26.425259-20752.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_26.425259-20752.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.274089-37780.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.274089-37780.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.922842-37724.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.922842-37724.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.395425-37800.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.395425-37800.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.200909-37768.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.200909-37768.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_00.941717-34504.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_00.941717-34504.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.372200-37640.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.372200-37640.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_13.831353-1260.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_13.831353-1260.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_38.388497-13700.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_38.388497-13700.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.176219-37764.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.176219-37764.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_37.184475-22324.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_37.184475-22324.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_33.475201-4156.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_33.475201-4156.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.897008-37720.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.897008-37720.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.050834-37744.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.050834-37744.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.609906-37836.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.609906-37836.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.151164-37760.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.151164-37760.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_34.312109-30636.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_34.312109-30636.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.974683-37732.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.974683-37732.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.346807-37792.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.346807-37792.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_55.869793-25052.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_55.869793-25052.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.556639-37668.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.556639-37668.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_28.692363-12276.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_28.692363-12276.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_44.097283-23336.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_44.097283-23336.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_40.257861-13972.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_40.257861-13972.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.298444-37784.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.298444-37784.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.844853-37712.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.844853-37712.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.000435-37736.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.000435-37736.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_51.029851-6736.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_51.029851-6736.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.583121-37672.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.583121-37672.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.249372-37776.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.249372-37776.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.688212-37688.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.688212-37688.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.025534-37740.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.025534-37740.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_40.149981-13956.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_40.149981-13956.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_48.586054-6376.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_48.586054-6376.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_29.163641-12344.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_29.163641-12344.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_30.873293-30136.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_30.873293-30136.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_01.831998-25920.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_01.831998-25920.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_21.237676-37468.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_21.237676-37468.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_28.471859-3416.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_28.471859-3416.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.766223-37700.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.766223-37700.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_58.982480-25504.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_58.982480-25504.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_41.091498-31620.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_41.091498-31620.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_05.243889-0.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_05.243889-0.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.443122-37808.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.443122-37808.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.727438-37856.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.727438-37856.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.740182-37696.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.740182-37696.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_06.004434-108.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_06.004434-108.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_21.000847-37432.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_21.000847-37432.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.635125-37680.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.635125-37680.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_36.568932-30964.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_36.568932-30964.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_43.506339-14452.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_43.506339-14452.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_39.403642-5024.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_39.403642-5024.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_41.177173-14108.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_41.177173-14108.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_31.094848-21436.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_31.094848-21436.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.076822-37748.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_23.076822-37748.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_02.223301-25972.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_02.223301-25972.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_25.953924-11872.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_25.953924-11872.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_24.122183-2776.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_24.122183-2776.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_11.205235-27280.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_11.205235-27280.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.948552-37728.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.948552-37728.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_48.699316-15212.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_48.699316-15212.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_43.734832-32004.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_43.734832-32004.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_47.985470-32620.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_47.985470-32620.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_51.842372-6856.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_51.842372-6856.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_30.274831-12508.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_30.274831-12508.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.539254-37824.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_23.539254-37824.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_56.400884-7528.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_56.400884-7528.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_31.726905-30260.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_31.726905-30260.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_04.710325-35052.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_04.710325-35052.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_56.541343-33864.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_56.541343-33864.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_51.742538-33168.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_51.742538-33168.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_34.868062-21988.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_34.868062-21988.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_44.360210-14576.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_44.360210-14576.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_19.494727-19732.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_19.494727-19732.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_27.581391-12112.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_27.581391-12112.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_07.743760-364.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_07.743760-364.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_16.596521-36780.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_16.596521-36780.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_59.221309-16760.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_59.221309-16760.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_39.496091-22664.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_39.496091-22664.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_54.141181-7196.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_54.141181-7196.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_29.792550-21244.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_29.792550-21244.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_26.128761-3068.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_26.128761-3068.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_40.609039-14024.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_40.609039-14024.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_23.384657-20304.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_23.384657-20304.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_22.529830-2540.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_22.529830-2540.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_22.870893-37716.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_22.870893-37716.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_21.197213-28728.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_21.197213-28728.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_02.604674-26028.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_02.604674-26028.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_01.968147-25940.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_01.968147-25940.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_57.451135-25280.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_57.451135-25280.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_08.827513-18168.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_08.827513-18168.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_12.048061-996.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_12.048061-996.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_09.121816-35692.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_09.121816-35692.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_18.625590-10796.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_18.625590-10796.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_40.121636-22756.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_40.121636-22756.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_40.133379-5132.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_40.133379-5132.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_35.073303-4388.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_35.073303-4388.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_15.038575-19080.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_15.038575-19080.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_34.189086-21888.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_34.189086-21888.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_58.622371-7856.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_58.622371-7856.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_19.718212-2124.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_19.718212-2124.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_28.840471-29840.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_28.840471-29840.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_26.688504-29528.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_26.688504-29528.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_38.958027-13784.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_38.958027-13784.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_37.777916-31140.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_37.777916-31140.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_33.987719-4232.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_33.987719-4232.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_53.851844-24756.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_53.851844-24756.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_38.628095-31264.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_38.628095-31264.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_31.828405-21544.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_31.828405-21544.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_06.109710-26540.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_06.109710-26540.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_06.412181-35300.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_06.412181-35300.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_41.783760-23000.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_41.783760-23000.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_26.219665-38260.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_26.219665-38260.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_09.939507-18332.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_09.939507-18332.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_13.722902-10076.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_13.722902-10076.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_05.099205-8804.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_05.099205-8804.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_05.918656-26512.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_05.918656-26512.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_33.801142-13028.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_33.801142-13028.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_44.648319-5796.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_44.648319-5796.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_12.433920-1053.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_12.433920-1053.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_24.098376-37920.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_24.098376-37920.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_19.298219-10894.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_19.298219-10894.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_52.674591-6979.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_52.674591-6979.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_57.180588-16459.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_57.180588-16459.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_12.082370-9835.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_12.082370-9835.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_40.754555-31571.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_40.754555-31571.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_19.073598-19670.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_19.073598-19670.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_42.842340-23151.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_42.842340-23151.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_43.696597-23277.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_43.696597-23277.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_16.982511-1724.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_16.982511-1724.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_49.273244-32808.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_49.273244-32808.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_55.519967-7398.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_55.519967-7398.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_03.886649-34932.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_03.886649-34932.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_46.809153-23730.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_46.809153-23730.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_44.793351-14640.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_44.793351-14640.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_13.974679-10113.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_13.974679-10113.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_03.976368-34945.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_03.976368-34945.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_31.783952-39150.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_31.783952-39150.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_52.600899-15786.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_52.600899-15786.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_19.998506-28553.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_19.998506-28553.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_08.755670-514.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_08.755670-514.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_29.486732-21199.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_29.486732-21199.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_42.512190-14305.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_42.512190-14305.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_08.800844-35645.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_08.800844-35645.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_04.794533-8759.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_04.794533-8759.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_34.663837-39606.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_34.663837-39606.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_35.928010-39812.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_35.928010-39812.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_35.701609-30838.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_35.701609-30838.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_50.144112-24216.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_50.144112-24216.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_10.555323-775.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_10.555323-775.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_07.240305-35421.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_07.240305-35421.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_15.066109-1440.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_15.066109-1440.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_09.580826-35759.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_09.580826-35759.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_31.850992-3915.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_31.850992-3915.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_54.801333-7292.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_54.801333-7292.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_26.889293-12010.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_26.889293-12010.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_06_06.434748-26587.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_06_06.434748-26587.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_54.820814-24898.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_54.820814-24898.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_38.315494-40195.jpg
# Image file does not exist: D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_38.315494-40195.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_49.789866-24164.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_49.789866-24164.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_46.537064-23690.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_46.537064-23690.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_22.888701-20231.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_22.888701-20231.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_36.045334-4532.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_36.045334-4532.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_37.387842-13552.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_37.387842-13552.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_04_05.302462-8834.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_04_05.302462-8834.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_03_27.442080-3263.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_03_27.442080-3263.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_14.791079-36516.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_14.791079-36516.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_07_14.893987-36531.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_07_14.893987-36531.jpg
# 文件path为：D:/Bristol/finalCoursework/dataset/ECL_Images_Test\001/0/2022-09-26 08_05_58.338961-25410.jpg
# Saved processed image: D:/Bristol/finalCoursework/dataset/Processed_Images\001\0\001/0/2022-09-26_08_05_58.338961-25410.jpg
# Loaded 161 images and 161 labels.
# Loaded 161 images with shape (299, 299, 3) and 161 labels.

# %%
# 检查数据形状
print("Images shape:", images.shape)
print("Labels shape:", labels.shape)
# Out:
# Images shape: (161, 299, 299, 3)
# Labels shape: (161, 12)

# %%
print(labels)
# Out:
# [[ 40.80104  127.697914 116.796875 ... 146.38542  238.57709  150.43437 ]
#  [ 50.767708 149.18854  118.04271  ... 165.38437  230.47917  167.25313 ]
#  [ 40.489582 127.697914 116.17396  ... 146.69687  237.64272  151.36874 ]
#  ...
#  [ 33.94896  120.84583  110.56771  ... 139.22188  234.83958  144.20522 ]
#  [ 34.260418 120.53438  110.56771  ... 138.59895  234.52812  143.89375 ]
#  [ 33.94896  118.97708  109.32188  ... 136.41875  234.83958  142.025   ]]

# %%
# # 定义模型
# def create_model(input_shape):
#     base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=input_shape) #加载预训练的 InceptionResNetV2 模型，使用 ImageNet 预训练的权重。
#     x = base_model.output  # 获取基础模型的输出，即 InceptionResNetV2 的最后一层输出。
#     x = GlobalAveragePooling2D()(x)
#     # 在基础模型的输出后添加全局平均池化层。
#     # GlobalAveragePooling2D() 会对每个特征图的空间维度进行全局平均池化，将其转换为单个值。
#     # 这将减少参数的数量并有助于防止过拟合。
#     x = Dense(512, activation='relu')(x)
#     # 添加一个全连接层（Dense 层），有 512 个神经元，使用 ReLU 激活函数。
#     # 这一层将学习到更加抽象和高层次的特征。
#     predictions = Dense(12, activation='linear')(x)
#     # 添加一个全连接层（Dense 层），有 12 个神经元，使用线性激活函数。
#     # 这一层的输出是 12 个值，适合用于回归任务，例如输出多个坐标值或其他连续值。
#     model = Model(inputs=base_model.input, outputs=predictions)
#     # 创建一个 Keras 模型，指定输入和输出。
#     # inputs=base_model.input 表示模型的输入是基础模型的输入。
#     # outputs=predictions 表示模型的输出是我们在基础模型顶部添加的自定义层的输出。
#     return model

def create_model(input_shape):
    base_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=input_shape)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # 添加Dropout层
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)  # 添加Dropout层
    predictions = Dense(12, activation='linear', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # 添加L2正则化
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

# %%
# 计算误差小于0.1条件下的准确率
def calculate_accuracy(predictions, labels, threshold=0.1):
    # errors = np.abs(predictions - labels)
    # accurate_predictions = np.all(errors < threshold, axis=1)
    # accuracy = np.mean(accurate_predictions)
    # return accuracy
    # 提取左眼和右眼的坐标
    pred_left_eye = predictions[:, 8:10]
    pred_right_eye = predictions[:, 10:12]
    true_left_eye = labels[:, 8:10]
    true_right_eye = labels[:, 10:12]
    print("pred_left_eye:", pred_left_eye)
    print("pred_right_eye",pred_right_eye)
    print("true_left_eye",true_left_eye)
    print("true_right_eye",true_right_eye)
    
    # 计算欧几里得距离
    left_eye_distances = np.linalg.norm(pred_left_eye - true_left_eye, axis=1)
    right_eye_distances = np.linalg.norm(pred_right_eye - true_right_eye, axis=1)
    
    # 判断距离是否在阈值范围内
    left_eye_accurate = left_eye_distances < threshold
    right_eye_accurate = right_eye_distances < threshold
    
    # 计算准确率
    accurate_predictions = np.logical_and(left_eye_accurate, right_eye_accurate)
    accuracy = np.mean(accurate_predictions)
    
    return accuracy

# %%
class AccuracyCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data, threshold=0.1):
        self.validation_data = validation_data
        self.threshold = threshold

    def on_epoch_end(self, epoch, logs=None):
        val_images, val_labels = self.validation_data
        predictions = self.model.predict(val_images)
        accuracy = calculate_accuracy(predictions, val_labels, threshold=self.threshold)
        print(f'Epoch {epoch+1}: accuracy = {accuracy:.2f}')

# %%
# # 分割训练和测试数据
# from sklearn.model_selection import train_test_split
train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size=0.2, random_state=42)

# 创建模型
model = create_model(input_shape=(299, 299, 3))

# 第一阶段：冻结预训练模型权重
for layer in model.layers[:-2]:
    layer.trainable = False

model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mean_squared_error')

# 训练模型（第一阶段）
callbacks = [
    ModelCheckpoint('model_stage2.keras', save_best_only=True),
    EarlyStopping(patience=5, restore_best_weights=True),
    AccuracyCallback(validation_data=(test_images, test_labels), threshold=0.1)
]

model.fit(train_images, train_labels, validation_split=0.2, epochs=10, callbacks=callbacks)

# 第二阶段：解冻整个模型的权重
for layer in model.layers:
    layer.trainable = True

model.compile(optimizer=tf.keras.optimizers.Adam(1e-5), loss='mean_squared_error')

# 训练模型（第二阶段）
callbacks = [
    ModelCheckpoint('model_stage2.keras', save_best_only=True),
    EarlyStopping(patience=5, restore_best_weights=True),
    AccuracyCallback(validation_data=(test_images, test_labels), threshold=0.1)
]

model.fit(train_images, train_labels, validation_split=0.2, epochs=10, callbacks=callbacks)

# 预测和计算准确率
predictions = model.predict(test_images)
accuracy = calculate_accuracy(predictions, test_labels)

print(f"Model accuracy with error threshold of 0.1: {accuracy:.2f}")

# 保存最终模型
model.save('final_eye_localization_model.keras')
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step  loss: 37250.01
# pred_left_eye: [[70.38052  15.431087]
#  [70.178406 15.712279]
#  [63.387432 14.244707]
#  [68.00074  15.326922]
#  [64.20763  14.368946]
#  [81.349144 17.680977]
#  [65.880394 14.982147]
#  [63.616882 14.190997]
#  [68.74768  15.231302]
#  [69.39196  15.642603]
#  [81.27019  18.05075 ]
#  [82.10834  17.767029]
#  [71.998474 16.603655]
#  [68.86603  15.039317]
#  [68.629166 15.349121]
#  [65.1475   14.70086 ]
#  [69.73681  15.707503]
#  [64.76058  14.63131 ]
#  [63.669636 14.213042]
#  [67.91591  15.030636]
#  [70.26753  15.751789]
#  [84.68539  18.07993 ]
#  [69.43419  15.864693]
#  [82.97388  17.344707]
#  [69.14984  15.388578]
#  [67.077614 14.96964 ]
#  [64.764656 14.428052]
#  [64.73955  14.574203]
#  [70.1832   15.835052]
#  [68.440506 15.349236]
#  [65.59358  14.779393]
#  [64.48299  14.314318]
#  [66.37219  14.817126]]
# pred_right_eye [[-2.290679   42.845207  ]
#  [-1.4367951  43.525784  ]
#  [-2.275508   36.84834   ]
#  [-1.7627476  40.861465  ]
#  [-2.01612    37.45197   ]
#  [ 1.7212096  59.46623   ]
#  [-2.4984655  38.662567  ]
#  [-3.0698538  37.33113   ]
#  [-2.8009577  41.153103  ]
#  [-1.4533643  42.63489   ]
#  [ 4.294463   61.650864  ]
#  [ 3.4002275  58.500465  ]
#  [10.299581   58.13157   ]
#  [-2.394454   42.157795  ]
#  [-0.31943408 42.53444   ]
#  [-1.8959969  39.425407  ]
#  [-1.4334573  42.890713  ]
#  [-2.9875784  38.16526   ]
#  [-2.174264   37.875496  ]
#  [-0.7221574  42.46172   ]
#  [-0.3681859  43.89499   ]
#  [ 3.1745863  60.634956  ]
#  [ 0.1359969  43.10022   ]
#  [ 1.8729907  59.068573  ]
#  [-0.9567422  42.875237  ]
#  [-1.4992551  40.83087   ]
#  [-1.7136658  38.233276  ]
#  [-2.9499502  38.56878   ]
#  [-1.4150876  43.395615  ]
#  [-1.4650372  41.8423    ]
#  [-2.3382845  38.78773   ]
#  [-2.4084578  37.911026  ]
#  [-1.4801763  40.17956   ]]
# true_left_eye [[ 74.75     135.48438 ]
#  [ 66.02917  136.10728 ]
#  [ 72.88125  141.40208 ]
#  [ 67.58646  139.53334 ]
#  [ 66.652084 141.40208 ]
#  [ 82.53646  157.59792 ]
#  [ 67.275    136.10728 ]
#  [ 66.96354  135.48438 ]
#  [ 69.76667  133.61563 ]
#  [ 70.38958  138.91042 ]
#  [ 82.53646  160.40105 ]
#  [ 78.79896  148.25417 ]
#  [ 82.225    171.61354 ]
#  [ 76.30729  135.17291 ]
#  [ 69.14375  143.58229 ]
#  [ 78.4875   140.77916 ]
#  [ 64.78333  137.97604 ]
#  [ 73.19271  134.55    ]
#  [ 54.505207 141.09062 ]
#  [ 66.96354  140.15625 ]
#  [ 70.70104  140.46771 ]
#  [ 79.421875 150.43437 ]
#  [ 69.76667  143.89375 ]
#  [ 81.91354  151.99167 ]
#  [ 71.32396  140.15625 ]
#  [ 71.32396  140.15625 ]
#  [ 66.96354  145.7625  ]
#  [ 72.25833  134.86147 ]
#  [ 64.78333  137.97604 ]
#  [ 68.83229  139.84479 ]
#  [ 66.652084 138.91042 ]
#  [ 66.96354  137.97604 ]
#  [ 60.422916 137.66458 ]]
# true_right_eye [[237.64272 139.84479]
#  [230.79062 139.53334]
#  [238.88853 145.7625 ]
#  [232.65938 142.95938]
#  [232.34792 144.82812]
#  [234.21666 161.02396]
#  [233.59375 139.84479]
#  [232.34792 138.59895]
#  [234.21666 137.66458]
#  [233.90521 143.27083]
#  [232.65938 164.13853]
#  [237.33125 153.86041]
#  [228.29897 174.41667]
#  [239.82292 139.84479]
#  [233.28229 148.87709]
#  [244.4948  146.07396]
#  [228.61041 142.64792]
#  [238.26562 138.2875 ]
#  [220.5125  144.82812]
#  [232.97084 145.13959]
#  [235.15105 145.13959]
#  [237.01979 154.79478]
#  [232.65938 149.18854]
#  [235.77396 155.72917]
#  [234.21666 145.45103]
#  [237.64272 145.13959]
#  [232.65938 150.12291]
#  [237.33125 139.53334]
#  [228.61041 141.71355]
#  [234.21666 145.45103]
#  [232.97084 143.58229]
#  [231.10208 141.09062]
#  [226.11874 142.64792]]
# Epoch 1: accuracy = 0.00
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 83s 19s/step - loss: 36830.6758 - val_loss: 19161.8281
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 495ms/steploss: 21719.5
# pred_left_eye: [[ 82.452225  55.27056 ]
#  [ 82.29607   55.69133 ]
#  [ 74.236824  50.047333]
#  [ 79.74126   54.04064 ]
#  [ 75.26989   50.84871 ]
#  [ 95.76857   65.788536]
#  [ 77.165375  52.231716]
#  [ 74.49692   50.10721 ]
#  [ 80.52151   54.081528]
#  [ 81.40671   55.26847 ]
#  [ 95.833755  66.740974]
#  [ 96.97252   67.01792 ]
#  [ 85.23998   60.8117  ]
#  [ 80.75234   54.258347]
#  [ 80.480034  54.46256 ]
#  [ 76.35004   51.707874]
#  [ 81.74059   55.307426]
#  [ 75.86581   51.291702]
#  [ 74.7025    50.609825]
#  [ 79.67735   53.86371 ]
#  [ 82.43666   55.89126 ]
#  [100.01741   68.937   ]
#  [ 81.46777   55.55596 ]
#  [ 97.91124   66.93134 ]
#  [ 81.14069   54.942936]
#  [ 78.63111   53.10801 ]
#  [ 75.89042   51.136326]
#  [ 75.86588   51.310295]
#  [ 82.297386  55.79594 ]
#  [ 80.25921   54.35568 ]
#  [ 76.88695   52.03782 ]
#  [ 75.6078    51.00947 ]
#  [ 77.89031   52.806274]]
# pred_right_eye [[ 40.390717  78.319824]
#  [ 41.395634  79.12489 ]
#  [ 36.08034   68.73059 ]
#  [ 39.71293   75.33542 ]
#  [ 37.065895  69.93686 ]
#  [ 53.265636 102.276245]
#  [ 37.40642   71.83421 ]
#  [ 35.40611   69.313614]
#  [ 38.81942   75.74808 ]
#  [ 41.00132   77.92076 ]
#  [ 56.4649   104.978714]
#  [ 56.170944 102.33615 ]
#  [ 57.671474  97.466675]
#  [ 39.621822  77.079384]
#  [ 41.585354  77.36258 ]
#  [ 37.750042  72.378494]
#  [ 40.99226   78.15384 ]
#  [ 36.285522  70.81082 ]
#  [ 36.817535  70.28452 ]
#  [ 40.881927  77.03965 ]
#  [ 42.637688  79.637665]
#  [ 57.66602  105.896774]
#  [ 42.663113  78.446976]
#  [ 55.00259  103.19682 ]
#  [ 41.42274   78.0965  ]
#  [ 39.35961   74.79174 ]
#  [ 37.61306   70.9211  ]
#  [ 36.4039    71.28119 ]
#  [ 41.397774  78.97986 ]
#  [ 40.32426   76.5762  ]
#  [ 37.57699   71.966385]
#  [ 36.903496  70.58677 ]
#  [ 39.21919   74.007965]]
# true_left_eye [[ 74.75     135.48438 ]
#  [ 66.02917  136.10728 ]
#  [ 72.88125  141.40208 ]
#  [ 67.58646  139.53334 ]
#  [ 66.652084 141.40208 ]
#  [ 82.53646  157.59792 ]
#  [ 67.275    136.10728 ]
#  [ 66.96354  135.48438 ]
#  [ 69.76667  133.61563 ]
#  [ 70.38958  138.91042 ]
#  [ 82.53646  160.40105 ]
#  [ 78.79896  148.25417 ]
#  [ 82.225    171.61354 ]
#  [ 76.30729  135.17291 ]
#  [ 69.14375  143.58229 ]
#  [ 78.4875   140.77916 ]
#  [ 64.78333  137.97604 ]
#  [ 73.19271  134.55    ]
#  [ 54.505207 141.09062 ]
#  [ 66.96354  140.15625 ]
#  [ 70.70104  140.46771 ]
#  [ 79.421875 150.43437 ]
#  [ 69.76667  143.89375 ]
#  [ 81.91354  151.99167 ]
#  [ 71.32396  140.15625 ]
#  [ 71.32396  140.15625 ]
#  [ 66.96354  145.7625  ]
#  [ 72.25833  134.86147 ]
#  [ 64.78333  137.97604 ]
#  [ 68.83229  139.84479 ]
#  [ 66.652084 138.91042 ]
#  [ 66.96354  137.97604 ]
#  [ 60.422916 137.66458 ]]
# true_right_eye [[237.64272 139.84479]
#  [230.79062 139.53334]
#  [238.88853 145.7625 ]
#  [232.65938 142.95938]
#  [232.34792 144.82812]
#  [234.21666 161.02396]
#  [233.59375 139.84479]
#  [232.34792 138.59895]
#  [234.21666 137.66458]
#  [233.90521 143.27083]
#  [232.65938 164.13853]
#  [237.33125 153.86041]
#  [228.29897 174.41667]
#  [239.82292 139.84479]
#  [233.28229 148.87709]
#  [244.4948  146.07396]
#  [228.61041 142.64792]
#  [238.26562 138.2875 ]
#  [220.5125  144.82812]
#  [232.97084 145.13959]
#  [235.15105 145.13959]
#  [237.01979 154.79478]
#  [232.65938 149.18854]
#  [235.77396 155.72917]
#  [234.21666 145.45103]
#  [237.64272 145.13959]
#  [232.65938 150.12291]
#  [237.33125 139.53334]
#  [228.61041 141.71355]
#  [234.21666 145.45103]
#  [232.97084 143.58229]
#  [231.10208 141.09062]
#  [226.11874 142.64792]]
# Epoch 2: accuracy = 0.00
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 45s 12s/step - loss: 21498.6328 - val_loss: 11389.3574
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 486ms/steploss: 14493.8
# pred_left_eye: [[ 85.540306  90.25808 ]
#  [ 85.40326   90.802216]
#  [ 77.003105  81.489456]
#  [ 82.736404  88.04065 ]
#  [ 78.08739   82.8871  ]
#  [ 99.51203  108.050705]
#  [ 80.036575  84.94298 ]
#  [ 77.27438   81.649864]
#  [ 83.527405  88.19956 ]
#  [ 84.48207   90.06976 ]
#  [ 99.62027  109.51509 ]
#  [100.84912  110.2868  ]
#  [ 88.6983    99.643105]
#  [ 83.80373   88.70256 ]
#  [ 83.52141   88.810684]
#  [ 79.2125    84.2079  ]
#  [ 84.809494  90.0835  ]
#  [ 78.700424  83.48682 ]
#  [ 77.52263   82.57523 ]
#  [ 82.69797   87.96733 ]
#  [ 85.55574   91.143684]
#  [104.010445 113.61818 ]
#  [ 84.54956   90.41489 ]
#  [101.796844 110.4975  ]
#  [ 84.21948   89.68521 ]
#  [ 81.58989   86.60018 ]
#  [ 78.73561   83.37248 ]
#  [ 78.70667   83.57283 ]
#  [ 85.39798   90.88968 ]
#  [ 83.286446  88.61026 ]
#  [ 79.76639   84.75748 ]
#  [ 78.44769   83.237686]
#  [ 80.83592   86.16919 ]]
# pred_right_eye [[ 80.799706 106.00647 ]
#  [ 81.94864  106.908356]
#  [ 72.39382   93.619354]
#  [ 78.98018  102.247055]
#  [ 74.06784   95.29741 ]
#  [102.08009  135.64186 ]
#  [ 75.18394   97.73126 ]
#  [ 71.83355   94.28023 ]
#  [ 78.22264  102.75098 ]
#  [ 81.19685  105.46178 ]
#  [105.87224  138.74422 ]
#  [106.147385 136.51872 ]
#  [102.5316   128.11526 ]
#  [ 79.40224  104.33346 ]
#  [ 81.25716  104.54409 ]
#  [ 75.28496   98.09857 ]
#  [ 81.1584   105.67584 ]
#  [ 73.46624   96.29414 ]
#  [ 73.73319   95.58211 ]
#  [ 80.27039  104.02437 ]
#  [ 83.35526  107.53334 ]
#  [109.272804 141.18913 ]
#  [ 82.92786  106.033356]
#  [105.32073  137.60428 ]
#  [ 81.550865 105.58502 ]
#  [ 78.0412   101.29809 ]
#  [ 74.844215  96.436035]
#  [ 73.66186   96.81614 ]
#  [ 81.93119  106.7518  ]
#  [ 79.88704  103.68509 ]
#  [ 75.36464   97.866486]
#  [ 74.12321   96.09456 ]
#  [ 77.75116  100.4131  ]]
# true_left_eye [[ 74.75     135.48438 ]
#  [ 66.02917  136.10728 ]
#  [ 72.88125  141.40208 ]
#  [ 67.58646  139.53334 ]
#  [ 66.652084 141.40208 ]
#  [ 82.53646  157.59792 ]
#  [ 67.275    136.10728 ]
#  [ 66.96354  135.48438 ]
#  [ 69.76667  133.61563 ]
#  [ 70.38958  138.91042 ]
#  [ 82.53646  160.40105 ]
#  [ 78.79896  148.25417 ]
#  [ 82.225    171.61354 ]
#  [ 76.30729  135.17291 ]
#  [ 69.14375  143.58229 ]
#  [ 78.4875   140.77916 ]
#  [ 64.78333  137.97604 ]
#  [ 73.19271  134.55    ]
#  [ 54.505207 141.09062 ]
#  [ 66.96354  140.15625 ]
#  [ 70.70104  140.46771 ]
#  [ 79.421875 150.43437 ]
#  [ 69.76667  143.89375 ]
#  [ 81.91354  151.99167 ]
#  [ 71.32396  140.15625 ]
#  [ 71.32396  140.15625 ]
#  [ 66.96354  145.7625  ]
#  [ 72.25833  134.86147 ]
#  [ 64.78333  137.97604 ]
#  [ 68.83229  139.84479 ]
#  [ 66.652084 138.91042 ]
#  [ 66.96354  137.97604 ]
#  [ 60.422916 137.66458 ]]
# true_right_eye [[237.64272 139.84479]
#  [230.79062 139.53334]
#  [238.88853 145.7625 ]
#  [232.65938 142.95938]
#  [232.34792 144.82812]
#  [234.21666 161.02396]
#  [233.59375 139.84479]
#  [232.34792 138.59895]
#  [234.21666 137.66458]
#  [233.90521 143.27083]
#  [232.65938 164.13853]
#  [237.33125 153.86041]
#  [228.29897 174.41667]
#  [239.82292 139.84479]
#  [233.28229 148.87709]
#  [244.4948  146.07396]
#  [228.61041 142.64792]
#  [238.26562 138.2875 ]
#  [220.5125  144.82812]
#  [232.97084 145.13959]
#  [235.15105 145.13959]
#  [237.01979 154.79478]
#  [232.65938 149.18854]
#  [235.77396 155.72917]
#  [234.21666 145.45103]
#  [237.64272 145.13959]
#  [232.65938 150.12291]
#  [237.33125 139.53334]
#  [228.61041 141.71355]
#  [234.21666 145.45103]
#  [232.97084 143.58229]
#  [231.10208 141.09062]
#  [226.11874 142.64792]]
# Epoch 3: accuracy = 0.00
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 47s 13s/step - loss: 14370.1318 - val_loss: 6468.4888
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 469ms/steploss: 11157.5
# pred_left_eye: [[ 82.605316 115.94704 ]
#  [ 82.4625   116.58244 ]
#  [ 74.35179  104.57048 ]
#  [ 79.87335  113.00339 ]
#  [ 75.38318  106.4076  ]
#  [ 96.00632  139.0794  ]
#  [ 77.28207  108.957184]
#  [ 74.61536  104.805664]
#  [ 80.660126 113.24866 ]
#  [ 81.56105  115.622375]
#  [ 96.08099  140.92114 ]
#  [ 97.27652  142.0694  ]
#  [ 85.52118  128.15828 ]
#  [ 80.92126  113.99392 ]
#  [ 80.658554 114.030334]
#  [ 76.483635 108.06758 ]
#  [ 81.892586 115.617134]
#  [ 75.99065  107.122086]
#  [ 74.84159  106.04385 ]
#  [ 79.85596  113.00859 ]
#  [ 82.60447  117.02965 ]
#  [100.32123  146.43517 ]
#  [ 81.62508  116.01158 ]
#  [ 98.19517  142.49258 ]
#  [ 81.29743  115.19783 ]
#  [ 78.790276 111.190994]
#  [ 76.03481  107.039185]
#  [ 75.99137  107.258446]
#  [ 82.456985 116.65712 ]
#  [ 80.42286  113.76074 ]
#  [ 77.01572  108.77912 ]
#  [ 75.733376 106.898094]
#  [ 78.03809  110.665436]]
# pred_right_eye [[116.387405 115.495895]
#  [117.66214  116.42871 ]
#  [104.3737   102.15633 ]
#  [113.56117  111.475525]
#  [106.654106 103.9953  ]
#  [145.07974  147.0133  ]
#  [108.45238  106.620056]
#  [103.91486  102.84245 ]
#  [112.9241   112.01063 ]
#  [116.59527  114.90045 ]
#  [149.39339  150.2591  ]
#  [150.17087  148.18152 ]
#  [142.0446   138.57742 ]
#  [114.43709  113.669785]
#  [116.19415  113.86214 ]
#  [108.34186  106.91531 ]
#  [116.52997  115.11134 ]
#  [106.21077  105.03438 ]
#  [106.24483  104.25404 ]
#  [114.95946  113.27084 ]
#  [119.21347  117.09207 ]
#  [154.73294  153.22804 ]
#  [118.38626  115.48754 ]
#  [149.64645  149.33676 ]
#  [116.89097  114.99719 ]
#  [112.10683  110.3865  ]
#  [107.63231  105.186676]
#  [106.47473  105.571724]
#  [117.62659  116.27042 ]
#  [114.72897  112.97876 ]
#  [108.6427   106.75134 ]
#  [106.90194  104.840225]
#  [111.68497  109.46661 ]]
# true_left_eye [[ 74.75     135.48438 ]
#  [ 66.02917  136.10728 ]
#  [ 72.88125  141.40208 ]
#  [ 67.58646  139.53334 ]
#  [ 66.652084 141.40208 ]
#  [ 82.53646  157.59792 ]
#  [ 67.275    136.10728 ]
#  [ 66.96354  135.48438 ]
#  [ 69.76667  133.61563 ]
#  [ 70.38958  138.91042 ]
#  [ 82.53646  160.40105 ]
#  [ 78.79896  148.25417 ]
#  [ 82.225    171.61354 ]
#  [ 76.30729  135.17291 ]
#  [ 69.14375  143.58229 ]
#  [ 78.4875   140.77916 ]
#  [ 64.78333  137.97604 ]
#  [ 73.19271  134.55    ]
#  [ 54.505207 141.09062 ]
#  [ 66.96354  140.15625 ]
#  [ 70.70104  140.46771 ]
#  [ 79.421875 150.43437 ]
#  [ 69.76667  143.89375 ]
#  [ 81.91354  151.99167 ]
#  [ 71.32396  140.15625 ]
#  [ 71.32396  140.15625 ]
#  [ 66.96354  145.7625  ]
#  [ 72.25833  134.86147 ]
#  [ 64.78333  137.97604 ]
#  [ 68.83229  139.84479 ]
#  [ 66.652084 138.91042 ]
#  [ 66.96354  137.97604 ]
#  [ 60.422916 137.66458 ]]
# true_right_eye [[237.64272 139.84479]
#  [230.79062 139.53334]
#  [238.88853 145.7625 ]
#  [232.65938 142.95938]
#  [232.34792 144.82812]
#  [234.21666 161.02396]
#  [233.59375 139.84479]
#  [232.34792 138.59895]
#  [234.21666 137.66458]
#  [233.90521 143.27083]
#  [232.65938 164.13853]
#  [237.33125 153.86041]
#  [228.29897 174.41667]
#  [239.82292 139.84479]
#  [233.28229 148.87709]
#  [244.4948  146.07396]
#  [228.61041 142.64792]
#  [238.26562 138.2875 ]
#  [220.5125  144.82812]
#  [232.97084 145.13959]
#  [235.15105 145.13959]
#  [237.01979 154.79478]
#  [232.65938 149.18854]
#  [235.77396 155.72917]
#  [234.21666 145.45103]
#  [237.64272 145.13959]
#  [232.65938 150.12291]
#  [237.33125 139.53334]
#  [228.61041 141.71355]
#  [234.21666 145.45103]
#  [232.97084 143.58229]
#  [231.10208 141.09062]
#  [226.11874 142.64792]]
# Epoch 4: accuracy = 0.00
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 46s 13s/step - loss: 11156.9297 - val_loss: 3697.4048
# Epoch 5/10
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 17s 9s/step - loss: 9336.6406
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 21
#      14 # 训练模型（第一阶段）
#      15 callbacks = [
#      16     ModelCheckpoint('model_stage2.keras', save_best_only=True),
#      17     EarlyStopping(patience=5, restore_best_weights=True),
#      18     AccuracyCallback(validation_data=(test_images, test_labels), threshold=0.1)
#      19 ]
# ---> 21 model.fit(train_images, train_labels, validation_split=0.2, epochs=10, callbacks=callbacks)
#      23 # 第二阶段：解冻整个模型的权重
#      24 for layer in model.layers:
#
# File d:\Anaconda3\envs\text_analytics\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Anaconda3\envs\text_analytics\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:318, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316 for step, iterator in epoch_iterator.enumerate_epoch():
#     317     callbacks.on_train_batch_begin(step)
# --> 318     logs = self.train_function(iterator)
#     319     logs = self._pythonify_logs(logs)
#     320     callbacks.on_train_batch_end(step, logs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\context.py:1667, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1665 cancellation_context = cancellation.context()
#    1666 if cancellation_context is None:
# -> 1667   outputs = execute.execute(
#    1668       name.decode("utf-8"),
#    1669       num_outputs=num_outputs,
#    1670       inputs=tensor_inputs,
#    1671       attrs=attrs,
#    1672       ctx=self,
#    1673   )
#    1674 else:
#    1675   outputs = execute.execute_with_cancellation(
#    1676       name.decode("utf-8"),
#    1677       num_outputs=num_outputs,
#    (...)
#    1681       cancellation_manager=cancellation_context,
#    1682   )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
